# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# %%
actual = np.array(['DOG','DOG','DOG','DOG','DOG','CAT','CAT','CAT','CAT','CAT'])
predicted = np.array(['DOG','DOG','DOG','DOG','DOG','CAT','CAT','CAT','CAT','CAT'])

# %%
cm = confusion_matrix(actual,predicted)
cm
# Out:
# array([[5, 0],
#        [0, 5]])

# %%
print(cm)
# Out:
# [[5 0]
#  [0 5]]
